# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
datasets=pd.get_dummies(dataset,drop_first=True)

# %%
datasets
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
datasets.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=datasets[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=datasets[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.53963418,  0.11036616, -0.90788827, -0.98885138, -0.49929923],
#        [ 0.74809711,  0.26412451, -0.0755796 ,  1.01127431,  2.00280702],
#        [ 0.4621307 ,  2.13997636,  1.58903774,  1.01127431, -0.49929923],
#        ...,
#        [ 0.03318108, -0.90443894, -0.90788827,  1.01127431, -0.49929923],
#        [-1.46814257,  0.7869029 , -0.90788827,  1.01127431, -0.49929923],
#        [-0.46726014, -1.96941782, -0.0755796 , -0.98885138, -0.49929923]])

# %%
X_test
# Out:
# array([[ 0.89108031, -0.07576237, -0.0755796 ,  1.01127431, -0.49929923],
#        [ 0.5336223 , -0.21009861, -0.0755796 , -0.98885138, -0.49929923],
#        [ 0.6051139 ,  1.60182214,  0.75672907,  1.01127431,  2.00280702],
#        ...,
#        [-1.46814257,  0.65256665,  0.75672907, -0.98885138,  2.00280702],
#        [-0.82471815,  0.37742013,  1.58903774,  1.01127431, -0.49929923],
#        [ 0.89108031,  1.24817794,  0.75672907, -0.98885138, -0.49929923]])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['mse','mae'],
              'max_features': ['auto','sqrt','log2'],
              'n_estimators':[10,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# C:\Users\SRIRAM\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   38.7s
# [Parallel(n_jobs=-1)]: Done  26 out of  36 | elapsed:   51.6s remaining:   19.8s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:   59.4s finished
# C:\Users\SRIRAM\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:715: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'mse', 'max_features': 'log2', 'n_estimators': 100}: 0.8709651743089584

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.092752      0.045142         0.002992    0.000000e+00
# 1        0.561394      0.019060         0.035904    2.634938e-02
# 2        0.288076      0.088056         0.003325    4.701340e-04
# 3        0.484562      0.126760         0.017287    8.475104e-03
# 4        0.084108      0.012466         0.002659    4.697969e-04
# 5        0.388628      0.008476         0.011968    1.628689e-03
# 6        0.246005      0.014671         0.002660    4.702464e-04
# 7        2.426513      0.080052         0.025266    2.233575e-02
# 8        0.210105      0.051742         0.003324    4.700779e-04
# 9        1.502982      0.316965         0.011303    2.049357e-03
# 10       0.271275      0.070329         0.002992    1.123916e-07
# 11       1.933861      0.106987         0.026269    2.374188e-02
#
#    param_criterion param_max_features param_n_estimators  \
# 0              mse               auto                 10
# 1              mse               auto                100
# 2              mse               sqrt                 10
# 3              mse               sqrt                100
# 4              mse               log2                 10
# 5              mse               log2                100
# 6              mae               auto                 10
# 7              mae               auto                100
# 8              mae               sqrt                 10
# 9              mae               sqrt                100
# 10             mae               log2                 10
# 11             mae               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.760683
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.781950
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.764106
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.811256
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.787644
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.807966
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.752398
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.790108
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.772553
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.802168
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.769829
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.803441
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.774393           0.787819         0.774283        0.011082
# 1            0.794248           0.794696         0.790289        0.005909
# 2            0.783993           0.798137         0.782059        0.013964
# 3            0.800576           0.793697         0.801854        0.007227
# 4            0.798336           0.786407         0.790792        0.005354
# 5            0.805090           0.795072         0.802715        0.005526
# 6            0.759413           0.779420         0.763731        0.011449
# 7            0.790767           0.790740         0.790538        0.000305
# 8            0.755305           0.788826         0.772228        0.013679
# 9            0.807547           0.791333         0.800351        0.006739
# 10           0.773244           0.766776         0.769950        0.002641
# 11           0.800900           0.794815         0.799723        0.003619
#
#     rank_test_score
# 0                 9
# 1                 7
# 2                 8
# 3                 2
# 4                 5
# 5                 1
# 6                12
# 7                 6
# 8                10
# 9                 3
# 10               11
# 11                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:29
# BMI:25
# Children:0
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[46957.1212414]
